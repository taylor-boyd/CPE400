# %%
# Assuming all destinations are [5,6]
# Test 1

n0 = Node(0, 10, [3, 5])
n1 = Node(1, 10, [3, 1])
n2 = Node(2, 10, [1, 3])
n3 = Node(3, 10, [6, 3])
# Adding a bit more
n4 = Node(4, 10, [2, 1])
n5 = Node(5, 10, [4, 1])
n6 = Node(6, 10, [4, 4])
n7 = Node(7, 10, [3, 2])
n8 = Node(8, 10, [5, 4])
n9 = Node(9, 10, [2, 6])

# list of nodes so it's easy to pass them to a function
nodes = [n0, n1, n2, n3, n4, n5, n6, n7, n8, n9]


# Test 2

n0 = Node(0, 10, [4, 8])
n1 = Node(1, 10, [6, 3])
n2 = Node(2, 10, [8, 8])
n3 = Node(3, 10, [4, 4])
n4 = Node(4, 10, [2, 2])
n5 = Node(5, 10, [2, 6])

nodes = [n0, n1, n2, n3, n4, n5]

# Test 3 

n0 = Node(0, 10, [4, 8])
n1 = Node(1, 10, [6, 7])
n2 = Node(2, 10, [8, 8])
n3 = Node(3, 10, [6, 6])
n4 = Node(4, 10, [4, 6])
n5 = Node(5, 10, [5, 5])
n6 = Node(6, 10, [6, 10])

nodes = [n0, n1, n2, n3, n4, n5, n6]


# Test 4

n0 = Node(0, 10, [0, 2])
n1 = Node(1, 10, [1, 2])
n2 = Node(2, 10, [4, 2])
n3 = Node(3, 10, [3, 1])
n4 = Node(4, 10, [2, 0])

nodes = [n0, n1, n2, n3, n4]


# Test 5
n0 = Node(0, 10, [6, 1])
n1 = Node(1, 10, [1, 10])
n2 = Node(2, 10, [0, 6])
n3 = Node(3, 10, [2, 0])
n4 = Node(4, 10, [8, 11])
n5 = Node(5, 10, [10, 6])

nodes = [n0, n1, n2, n3, n4, n5]
